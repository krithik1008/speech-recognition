# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-804aab40-19f8-4ba2-b188-0656fe3568b5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-804aab40-19f8-4ba2-b188-0656fe3568b5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving my_model.zip to my_model.zip

# %%
import os
import IPython.display as ipd
import numpy as np
import librosa

# %%
import zipfile
import io
zf = zipfile.ZipFile(io.BytesIO(uploaded['my_model.zip']), "r")
zf.extractall()

# %%
from keras.models import load_model
model=load_model('my_model.h5')

# %%
def predict(audio):
    prob=model.predict(audio.reshape(1,8000,1))
    index=np.argmax(prob[0])
    return classes[index]

# %%
"""import sounddevice as sd
import soundfile as sf

samplerate = 16000  
duration = 1 # seconds
filename = 'yes.wav'
print("start")
mydata = sd.rec(int(samplerate * duration), samplerate=samplerate,
    channels=1, blocking=True)
print("end")
sd.wait()
sf.write(filename, mydata, samplerate)"""

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5d2e17c3-4eed-467e-b5be-427f1238eea4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5d2e17c3-4eed-467e-b5be-427f1238eea4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sample.zip to sample.zip

# %%
import zipfile
import io
zf = zipfile.ZipFile(io.BytesIO(uploaded['sample.zip']), "r")
zf.extractall()

# %%
labels=["yes", "no", "up", "down", "left", "right", "on", "off", "stop", "go"]

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
y=label.fit_transform(labels)
classes= list(label.classes_)

# %%
filepath='/content/sample/'

# %%
samples, sample_rate = librosa.load(filepath + '/' + 'left.wav', sr = 16000)
samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples,rate=8000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
predict(samples)
# Out:
# 'left'

# %%
samples, sample_rate = librosa.load(filepath + '/' + 'right.wav', sr = 16000)
samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples,rate=8000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
predict(samples)
# Out:
# 'right'

# %%
samples, sample_rate = librosa.load(filepath + '/' + 'yes.wav', sr = 16000)
samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples,rate=8000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
predict(samples)
# Out:
# 'yes'
